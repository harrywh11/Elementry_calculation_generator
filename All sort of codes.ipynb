# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
import math
import urllib
import os
import os.path as osp
import nbformat
import json
import ssl
import sys
import time
import hashlib
import pickle
import io
import random
import getpass
import inspect
import socket
import tempfile
from datetime import datetime, date
from datetime import timedelta

import matplotlib
import pylab # for side effects on matplotlib
import pandas as pd
import numpy as np
import IPython.display as ipd

# %%
#functions
def array_to_html(arr, row_names=None, col_names=None, title=None):
    ''' array_to_html, if placed at the end of a Anaconda cell, will
        display the array in html.   It uses pandas.
    '''
    if len(arr.shape) not in [1, 2]:
        print('The array must be a one- or two-dimensional array. This array is',
             len(arr.shape), 'dimensions')
        return

    if title:
        ipd.display(ipd.HTML('<h1>' + title + '</h1>'))
    df = pd.DataFrame(arr, index=row_names, columns=col_names)
    return ipd.display(ipd.HTML(df.to_html()))

# %%
# produce problems multiply
MAX_range = 100
MIN_range = 10
num = 100
list1 = []
random.seed(1)
for i in range(0,num):
    a = random.randint(MIN_range, MAX_range)
    b = random.randint(MIN_range, MAX_range)
    list1.append(str(a)+' * '+str(b)+' = ')
array1 = np.array(list1)
array_to_html(array1,row_names=range(1,num+1),col_names=['Questions'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Questions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>27 * 82 =</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>18 * 42 =</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>25 * 73 =</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>67 * 70 =</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>93 * 58 =</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>36 * 22 =</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>72 * 13 =</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>59 * 65 =</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>87 * 10 =</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>99 * 67 =</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>44 * 39 =</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>85 * 23 =</td>
# ...

# %%
# produce problems with ans
MAX_range = 100
MIN_range = 10
num = 100
list1 = []
random.seed(1)
for i in range(0,num):
    a = random.randint(MIN_range, MAX_range)
    b = random.randint(MIN_range, MAX_range)
    c = (str(a)+' * '+str(b)+' = ')
    d = a*b
    list1.append([c,d])
array1 = np.array(list1)
array_to_html(array1,row_names=range(1,num+1),col_names=['Questions','Answers'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Questions</th>
#       <th>Answers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>27 * 82 =</td>
#       <td>2214</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>18 * 42 =</td>
#       <td>756</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>25 * 73 =</td>
#       <td>1825</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>67 * 70 =</td>
#       <td>4690</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>93 * 58 =</td>
#       <td>5394</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>36 * 22 =</td>
#       <td>792</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>72 * 13 =</td>
#       <td>936</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>59 * 65 =</td>
#       <td>3835</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>87 * 10 =</td>
#       <td>870</td>
# ...

# %%
# produce problems division
MAX_range = 100
MIN_range = 10
num = 100
list1 = []
random.seed(2)
for i in range(0,num):
    a = random.randint(MIN_range, MAX_range)
    b = random.randint(MIN_range, MAX_range)
    ab = a*b
    list1.append(str(ab)+' / '+str(b)+' = ')
array1 = np.array(list1)
array_to_html(array1,row_names=range(1,num+1),col_names=['Questions'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Questions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>357 / 21 =</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1120 / 56 =</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2945 / 95 =</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2058 / 42 =</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3219 / 37 =</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1218 / 14 =</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8148 / 97 =</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1950 / 65 =</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>5460 / 60 =</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>4275 / 57 =</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>5214 / 66 =</td>
#     </tr>
#     <tr>
#       <th>12</th>
# ...

# %%
# produce problems division
MAX_range = 100
MIN_range = 10
num = 100
list2 = []
random.seed(2)
for i in range(0,num):
    a = random.randint(MIN_range, MAX_range)
    b = random.randint(MIN_range, MAX_range)
    ab = a*b
    c = (str(ab)+' / '+str(b)+' = ')
    list2.append([c,a])
array1 = np.array(list2)
array_to_html(array1,row_names=range(1,num+1),col_names=['Questions','Answers'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Questions</th>
#       <th>Answers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>357 / 21 =</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1120 / 56 =</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2945 / 95 =</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2058 / 42 =</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3219 / 37 =</td>
#       <td>87</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1218 / 14 =</td>
#       <td>87</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8148 / 97 =</td>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1950 / 65 =</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>5460 / 60 =</td>
# ...
